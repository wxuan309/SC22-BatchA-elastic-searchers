# %% [markdown]
# ### Import packages

# %% [markdown]
# syntax:
# - `from ... import ...`
# - `import ... (as ...)`

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Dataset

# %% [markdown]
# syntax:
# - `df = pd.read_csv("filename or path to file")`

# %%
df = pd.read_csv("./diabetes_dataset__2019.csv")

# %%
df.head()
# Out:
#      Age Gender Family_Diabetes highBP      PhysicallyActive   BMI Smoking  \
# 0  50-59   Male              no    yes        one hr or more  39.0      no
# 1  50-59   Male              no    yes  less than half an hr  28.0      no
# 2  40-49   Male              no     no        one hr or more  24.0      no
# 3  50-59   Male              no     no        one hr or more  23.0      no
# 4  40-49   Male              no     no  less than half an hr  27.0      no
#
#   Alcohol  Sleep  SoundSleep RegularMedicine      JunkFood     Stress BPLevel  \
# 0      no    8.0         6.0              no  occasionally  sometimes    high
# 1      no    8.0         6.0             yes    very often  sometimes  normal
# 2      no    6.0         6.0              no  occasionally  sometimes  normal
# 3      no    8.0         6.0              no  occasionally  sometimes  normal
# 4      no    8.0         8.0              no  occasionally  sometimes  normal
#
#    Pregancies Pdiabetes UriationFreq Diabetic
# 0         0.0         0     not much       no
# 1         0.0         0     not much       no
# 2         0.0         0     not much       no
# 3         0.0         0     not much       no
# 4         0.0         0     not much       no

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               953 non-null    object
#  1   Gender            952 non-null    object
#  2   Family_Diabetes   952 non-null    object
#  3   highBP            952 non-null    object
#  4   PhysicallyActive  952 non-null    object
#  5   BMI               948 non-null    float64
#  6   Smoking           952 non-null    object
#  7   Alcohol           952 non-null    object
#  8   Sleep             952 non-null    float64
#  9   SoundSleep        952 non-null    float64
#  10  RegularMedicine   952 non-null    object
#  11  JunkFood          952 non-null    object
#  12  Stress            952 non-null    object
#  13  BPLevel           952 non-null    object
#  14  Pregancies        910 non-null    float64
#  15  Pdiabetes         951 non-null    object
#  16  UriationFreq      952 non-null    object
#  17  Diabetic          951 non-null    object
# dtypes: float64(4), object(14)
# memory usage: 134.1+ KB

# %%
df.shape
# Out:
# (953, 18)

# %% [markdown]
# #### syntax of retrieving one column of data
# - `df_name["column_name"]`

# %%
df["Pdiabetes"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#       ...
# 948      0
# 949      0
# 950      0
# 951      0
# 952    NaN
# Name: Pdiabetes, Length: 953, dtype: object

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### drop missing values (whole row/observation)
# - `df = df_name.dropna()`

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (905, 18)

# %% [markdown]
# #### Example of using `pd.get_dummies()`

# %%
sex = ['male', 'male', 'female', 'male', 'female']
s = pd.DataFrame(sex, columns = ['sex'])

# %%
s
# Out:
#       sex
# 0    male
# 1    male
# 2  female
# 3    male
# 4  female

# %%
s = pd.get_dummies(s, columns = ['sex'])
s
# Out:
#    sex_female  sex_male
# 0           0         1
# 1           0         1
# 2           1         0
# 3           0         1
# 4           1         0

# %% [markdown]
# #### Converting categorical variables into dummy variables
#
# - `df_name = pd.get_dummies(df_name, columns = [column_names])`

# %%
df = pd.get_dummies(df, columns = ['Gender', 'Smoking'])
df
# Out:
#               Age Family_Diabetes highBP      PhysicallyActive   BMI Alcohol  \
# 0           50-59              no    yes        one hr or more  39.0      no
# 1           50-59              no    yes  less than half an hr  28.0      no
# 2           40-49              no     no        one hr or more  24.0      no
# 3           50-59              no     no        one hr or more  23.0      no
# 4           40-49              no     no  less than half an hr  27.0      no
# ..            ...             ...    ...                   ...   ...     ...
# 947  less than 40             yes     no  more than half an hr  25.0      no
# 948   60 or older             yes    yes  more than half an hr  27.0      no
# 949   60 or older              no    yes                  none  23.0      no
# 950   60 or older              no    yes  less than half an hr  27.0     yes
# 951   60 or older             yes    yes        one hr or more  30.0      no
#
#      Sleep  SoundSleep RegularMedicine      JunkFood      Stress BPLevel  \
# 0      8.0         6.0              no  occasionally   sometimes    high
# 1      8.0         6.0             yes    very often   sometimes  normal
# 2      6.0         6.0              no  occasionally   sometimes  normal
# 3      8.0         6.0              no  occasionally   sometimes  normal
# 4      8.0         8.0              no  occasionally   sometimes  normal
# ..     ...         ...             ...           ...         ...     ...
# 947    8.0         6.0              no         often   sometimes  normal
# 948    6.0         5.0             yes  occasionally   sometimes    high
# 949    6.0         5.0             yes  occasionally   sometimes    high
# 950    6.0         5.0             yes  occasionally  very often    high
# 951    7.0         4.0             yes  occasionally   sometimes    high
#
#      Pregancies Pdiabetes UriationFreq Diabetic  Gender_Female  Gender_Male  \
# 0           0.0         0     not much       no              0            1
# 1           0.0         0     not much       no              0            1
# 2           0.0         0     not much       no              0            1
# 3           0.0         0     not much       no              0            1
# 4           0.0         0     not much       no              0            1
# ..          ...       ...          ...      ...            ...          ...
# 947         0.0         0     not much      yes              0            1
# 948         0.0         0  quite often      yes              0            1
# 949         0.0         0     not much       no              0            1
# 950         0.0         0     not much       no              0            1
# 951         2.0         0  quite often      yes              1            0
#
#      Smoking_no  Smoking_yes
# 0             1            0
# 1             1            0
# 2             1            0
# 3             1            0
# 4             1            0
# ..          ...          ...
# 947           1            0
# 948           1            0
# 949           1            0
# 950           1            0
# 951           1            0
#
# [905 rows x 20 columns]

# %% [markdown]
# #### Converting target variable \(yes/no\) into 0s and 1s

# %%
df['Diabetic'] = df['Diabetic'].replace('no', 0)
df['Diabetic'] = df['Diabetic'].replace(' no', 0)
df['Diabetic'] = df['Diabetic'].replace('yes', 1)
df['Diabetic']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 947    1
# 948    1
# 949    0
# 950    0
# 951    1
# Name: Diabetic, Length: 905, dtype: int64

# %% [markdown]
# ### Split data into training and testing
#
# - `train, test = train_test_split(df_name, test_size, shuffle = True)`

# %%
train, test = train_test_split(df, test_size = 0.2, shuffle = True)

# %%
train
# Out:
#               Age Family_Diabetes highBP      PhysicallyActive   BMI Alcohol  \
# 478         40-49              no     no        one hr or more  24.0      no
# 937         40-49             yes    yes  more than half an hr  33.0      no
# 102  less than 40              no    yes  less than half an hr  24.0      no
# 312         50-59             yes    yes                  none  31.0     yes
# 736  less than 40             yes     no        one hr or more  24.0      no
# ..            ...             ...    ...                   ...   ...     ...
# 771  less than 40              no     no  less than half an hr  29.0     yes
# 929  less than 40             yes     no  more than half an hr  29.0      no
# 678  less than 40              no     no        one hr or more  25.0      no
# 666  less than 40              no     no  less than half an hr  24.0     yes
# 184  less than 40             yes     no                  none  20.0      no
#
#      Sleep  SoundSleep RegularMedicine      JunkFood      Stress BPLevel  \
# 478    6.0         6.0              no  occasionally   sometimes  normal
# 937    7.0         2.0             yes  occasionally   sometimes    high
# 102    8.0         8.0              no  occasionally  very often  normal
# 312    7.0         6.0             yes  occasionally      always    high
# 736    4.0         4.0             yes         often      always  normal
# ..     ...         ...             ...           ...         ...     ...
# 771    6.0         5.0             yes         often  very often  normal
# 929    6.0         3.0              no  occasionally   sometimes  normal
# 678    6.0         6.0              no        always      always  normal
# 666   10.0         7.0              no        always      always  normal
# 184    9.0         9.0              no         often   sometimes  normal
#
#      Pregancies Pdiabetes UriationFreq  Diabetic  Gender_Female  Gender_Male  \
# 478         0.0         0     not much         0              0            1
# 937         0.0         0  quite often         1              1            0
# 102         0.0         0     not much         0              0            1
# 312         0.0         0     not much         1              0            1
# 736         3.0         0     not much         1              1            0
# ..          ...       ...          ...       ...            ...          ...
# 771         0.0         0     not much         0              0            1
# 929         0.0         0  quite often         0              1            0
# 678         0.0         0     not much         0              0            1
# 666         0.0         0     not much         0              0            1
# 184         0.0         0     not much         0              1            0
#
#      Smoking_no  Smoking_yes
# 478           1            0
# 937           1            0
# 102           1            0
# 312           1            0
# 736           1            0
# ..          ...          ...
# 771           0            1
# 929           1            0
# 678           1            0
# 666           0            1
# 184           1            0
#
# [724 rows x 20 columns]

# %%
test
# Out:
#               Age Family_Diabetes highBP      PhysicallyActive   BMI Alcohol  \
# 949   60 or older              no    yes                  none  23.0      no
# 41    60 or older              no     no                  none  24.0      no
# 360  less than 40              no    yes  more than half an hr  26.0      no
# 797  less than 40              no     no  less than half an hr  28.0     yes
# 497  less than 40             yes     no        one hr or more  24.0      no
# ..            ...             ...    ...                   ...   ...     ...
# 335  less than 40              no     no  more than half an hr  24.0      no
# 709  less than 40             yes     no  more than half an hr  22.0      no
# 791         50-59              no    yes                  none  20.0      no
# 600         50-59              no    yes  less than half an hr  33.0     yes
# 19   less than 40             yes     no        one hr or more  22.0      no
#
#      Sleep  SoundSleep RegularMedicine      JunkFood      Stress BPLevel  \
# 949    6.0         5.0             yes  occasionally   sometimes    high
# 41     6.0         6.0              no  occasionally   sometimes  normal
# 360    6.0         6.0              no  occasionally   sometimes  normal
# 797    4.0         4.0              no  occasionally  very often  normal
# 497    4.0         4.0             yes         often      always  normal
# ..     ...         ...             ...           ...         ...     ...
# 335    8.0         5.0              no         often  not at all  normal
# 709    8.0         6.0              no         often   sometimes  normal
# 791    7.0         4.0             yes  occasionally   sometimes    high
# 600    5.0         5.0             yes  occasionally   sometimes    high
# 19     8.0         6.0              no         often  not at all  normal
#
#      Pregancies Pdiabetes UriationFreq  Diabetic  Gender_Female  Gender_Male  \
# 949         0.0         0     not much         0              0            1
# 41          0.0         0     not much         0              0            1
# 360         0.0         0  quite often         0              0            1
# 797         0.0         0     not much         0              0            1
# 497         3.0         0  quite often         1              1            0
# ..          ...       ...          ...       ...            ...          ...
# 335         0.0         0     not much         0              0            1
# 709         0.0         0     not much         1              0            1
# 791         1.0         0     not much         1              1            0
# 600         0.0         0     not much         0              0            1
# 19          0.0         0     not much         0              0            1
#
#      Smoking_no  Smoking_yes
# 949           1            0
# 41            1            0
# 360           1            0
# 797           0            1
# 497           1            0
# ..          ...          ...
# 335           1            0
# 709           1            0
# 791           1            0
# 600           1            0
# 19            1            0
#
# [181 rows x 20 columns]

# %% [markdown]
# ### Model fitting

# %% [markdown]
# #### example of using logistic regression

# %%
xcols = ['BMI']
lr = LogisticRegression()
lr.fit(train[xcols], train['Diabetic'])
lr.score(test[xcols], test['Diabetic'])
# Out:
# 0.7348066298342542

# %%
count = 0
coun = 0
for i in df['Diabetic']:
    if i == 0:
        count += 1
    else:
        coun += 1

# %%
count
# Out:
# 642

# %%
coun
# Out:
# 263
